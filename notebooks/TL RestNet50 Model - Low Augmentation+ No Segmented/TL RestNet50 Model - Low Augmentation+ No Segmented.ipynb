# %%
from pathlib import Path

import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import itertools 

from PIL import Image
import cv2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, CSVLogger
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import Callback
from timeit import default_timer as timer

# %% [markdown]
# ### Chargement des données

# %%
# Chargement du DataFrame contenant le chemin d'accès à chaque image et l'espèce correspondante (label)
df = pd.read_csv("V2_Plant_Seedlings_DataFrame.csv")
df.head()
# Out:
#                                             filepath      species image_name  \
# 0  C:\Users\zammi\Desktop\DATA_SCIENCE\Projet_ re...  Black-grass     15.png
# 1  C:\Users\zammi\Desktop\DATA_SCIENCE\Projet_ re...  Black-grass     88.png
# 2  C:\Users\zammi\Desktop\DATA_SCIENCE\Projet_ re...  Black-grass    151.png
# 3  C:\Users\zammi\Desktop\DATA_SCIENCE\Projet_ re...  Black-grass    278.png
# 4  C:\Users\zammi\Desktop\DATA_SCIENCE\Projet_ re...  Black-grass    182.png
#
#    height  width     R_mean     G_mean     B_mean  luminosity  \
# 0     147    147  86.006109  69.395668  51.121894   68.841224
# 1     181    181  72.084155  57.116999  42.875004   57.358719
# 2     638    638  87.168107  68.065462  49.185226   68.139598
# 3     531    531  90.145336  79.522381  69.335855   79.667857
# 4     115    115  85.214820  68.097467  47.529301   66.947196
#
#    sharpness_score  image_size  square
# 0         8.013780       21609  square
# 1        10.732770       32761  square
# 2       127.819102      407044  square
# 3        99.007011      281961  square
# 4         3.812277       13225  square

# %% [markdown]
# ### Séparation des jeux d'entraînement et de test

# %%
# Train/test split: 80% dans le jeu train, 20% dans le jeu test
train_df,test_df = train_test_split(df,
                                    test_size=0.2,
                                    random_state=3,
                                    shuffle=True,
                                    stratify=df['species'])

# %% [markdown]
# ### Pre-processing

# %%
# Paramètres de preprocessing
color_mode = 'rgb'
target_size = (224,224)
channels = 3
batch_size = 32

# %%
# Instanciation du générateur de données

# Générateur des données d'entraînement: avec augmentation "faible" des données sans segmentation
train_data_generator = ImageDataGenerator(preprocessing_function= preprocess_input, # Fonction de pre-processing propre au modèle
                                          rotation_range=90,
                                          width_shift_range=0.05,
                                          height_shift_range=0.05,
                                          vertical_flip=True,
                                          horizontal_flip=True,
                                          validation_split=0.2) # 20% du jeu train est réservé pour évaluer le modèle au cours de l'entraînement


# Générateur des données de test: avec augmentation de données et sans segmentation
test_data_generator = ImageDataGenerator(preprocessing_function= preprocess_input,)

# %%
# Instanciation des itérateurs associés aux trois jeux train, validation et test
train_iterator = train_data_generator.flow_from_dataframe(train_df,
                                                           x_col='filepath',
                                                           y_col='species',
                                                           target_size=target_size,
                                                           color_mode=color_mode,
                                                           class_mode='sparse',
                                                           batch_size=batch_size,
                                                           subset="training")

validation_iterator = train_data_generator.flow_from_dataframe(train_df,
                                                               x_col='filepath',
                                                               y_col='species',
                                                               target_size=target_size,
                                                               color_mode=color_mode,
                                                               class_mode='sparse',
                                                               batch_size=batch_size,
                                                               subset="validation")

test_iterator = test_data_generator.flow_from_dataframe(test_df,
                                                         x_col='filepath',
                                                         y_col='species',
                                                         target_size=target_size,
                                                         color_mode=color_mode,
                                                         class_mode='sparse',
                                                         batch_size=batch_size,
                                                         shuffle=False)
# Out:
# Found 3545 validated image filenames belonging to 12 classes.
# Found 886 validated image filenames belonging to 12 classes.
# Found 1108 validated image filenames belonging to 12 classes.

# %% [markdown]
# ### Construction du modèle, définition des callbacks

# %%
# Transfer learning sur la base du modèle RestNet50

# Chargement du modèle de baseRestNet50 pré-entraîné sur la base de données ImageNet

# Chargement du modèle de base pré-entraîné
base_model = ResNet50(weights='imagenet',
                      input_shape=(target_size[0],target_size[1],channels), 
                      include_top=False,  # On conserve uniquement la partie convolutionnelle du modèle de base
                      pooling='avg')

base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# Création du modèle complet: construction fonctionnelle

inputs = Input(shape=(target_size[0],target_size[1],channels),name='Input')
          
# Définition des couches de classification
classif_layer1 = Dropout(rate=0.2,name='Dropout_layer_1')
classif_layer2 = Dense(units=256,activation='relu',name='Dense_layer_1')
classif_layer3 = Dropout(rate=0.2,name='Dropout_layer_2')
classif_layer4 = Dense(units=128,activation='relu',name='Dense_layer_2')
classif_layer5 = Dropout(rate=0.2,name='Dropout_layer_3')
output_layer = Dense(units=12,activation='softmax',name='Dense_layer_output')

# Assemblage du modèle
x = base_model(inputs)
x = classif_layer1(x)
x = classif_layer2(x)
x = classif_layer3(x)
x = classif_layer4(x)
x = classif_layer5(x)
outputs = output_layer(x)

model = Model(inputs = inputs, outputs = outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 224, 224, 3)]     0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  Dropout_layer_1 (Dropout)   (None, 2048)              0
#
#  Dense_layer_1 (Dense)       (None, 256)               524544
#
#  Dropout_layer_2 (Dropout)   (None, 256)               0
#
#  Dense_layer_2 (Dense)       (None, 128)               32896
#
#  Dropout_layer_3 (Dropout)   (None, 128)               0
#
#  Dense_layer_output (Dense)  (None, 12)                1548
#
# =================================================================
# Total params: 24,146,700
# Trainable params: 558,988
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# Définition des callbacks 

reduce_learning_rate = ReduceLROnPlateau(monitor='val_accuracy',
                                         factor=0.5,
                                         min_delta=0.01,
                                         mode='max',
                                         patience=3,
                                         verbose=1)


# Callback mesurant la durée de l'entraînement
class TimingCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_train_begin(self, logs={}):
        self.starttime = timer()
    def on_train_end(self, logs={}):
        self.logs.append(timer()-self.starttime)

time_callback = TimingCallback()

# %%
# Fonction permettant de charger un éventuel modèle précédemment entraîné, de compiler et de lancer l'entraînement

def model_load_and_fit(checkpoint_filepath,csvlogger_filepath,loadweights_filepath=None,lr=1.e-3,nb_epochs=30):
    
    # Chargement des poids obtenus lors d'un précédent entraînement
    if loadweights_filepath != None:
        print("Loading model weights")
        model.load_weights(loadweights_filepath)
        
    # Compilation
    print("Compiling model")
    model.compile(optimizer=Adam(learning_rate=lr),loss='sparse_categorical_crossentropy',metrics='accuracy')
    model.optimizer.lr.assign(lr)    # Assignation forcée pour éviter l'utilisation du LR chargé avec les poids (bug Keras?)
    print("Model compilation OK, learning rate =",model.optimizer.lr.numpy())
    
    # Définition du ModelCheckPoint
    model_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath,
                                       monitor='val_accuracy',
                                       mode='max',
                                       save_best_only = True,
                                       save_weights_only = True,
                                       verbose=1)
    
    # Définition du CSV Logger (enregistrement de l'historique d'entraînement)
    csv_logger = CSVLogger(csvlogger_filepath,append=True)
    
    # Entraînement
    print("Launching training")
    training_history = model.fit(train_iterator,validation_data=validation_iterator,
                                 epochs=nb_epochs,
                                 steps_per_epoch=train_iterator.samples//batch_size,
                                 validation_steps=validation_iterator.samples//batch_size,
                                 callbacks=[time_callback,reduce_learning_rate,model_checkpoint,csv_logger],
                                 verbose=True)

# %% [markdown]
# ### Entraînement du modèle

# %% [markdown]
# #### Etape 1: Entraînement avec les poids du modèle de base freezés¶

# %%
# Freeze des poids du modèle de base

for layer in base_model.layers:
    layer.trainable = False

# %%
# Définition des paramètres d'entraînement
checkpoint_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','Freeze','best_weights.ckpt')
csvlogger_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','Freeze','training_history.csv')

# %%
# Lancement de l'entraînement
model_load_and_fit(checkpoint_filepath,csvlogger_filepath)
# Out:
# Compiling model
# Model compilation OK, learning rate = 0.001
# Launching training
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 1.9109 - accuracy: 0.3570
# Epoch 1: val_accuracy improved from -inf to 0.63542, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 129s 1s/step - loss: 1.9109 - accuracy: 0.3570 - val_loss: 1.1069 - val_accuracy: 0.6354 - lr: 0.0010
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 1.1084 - accuracy: 0.6225
# Epoch 2: val_accuracy improved from 0.63542 to 0.76273, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 123s 1s/step - loss: 1.1084 - accuracy: 0.6225 - val_loss: 0.7138 - val_accuracy: 0.7627 - lr: 0.0010
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.8681 - accuracy: 0.6977
# Epoch 3: val_accuracy improved from 0.76273 to 0.79514, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 127s 1s/step - loss: 0.8681 - accuracy: 0.6977 - val_loss: 0.5673 - val_accuracy: 0.7951 - lr: 0.0010
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.7504 - accuracy: 0.7310
# Epoch 4: val_accuracy improved from 0.79514 to 0.80208, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 126s 1s/step - loss: 0.7504 - accuracy: 0.7310 - val_loss: 0.5718 - val_accuracy: 0.8021 - lr: 0.0010
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.6877 - accuracy: 0.7558
# Epoch 5: val_accuracy improved from 0.80208 to 0.82870, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 124s 1s/step - loss: 0.6877 - accuracy: 0.7558 - val_loss: 0.5067 - val_accuracy: 0.8287 - lr: 0.0010
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.6506 - accuracy: 0.7666
# Epoch 6: val_accuracy did not improve from 0.82870
# 110/110 [==============================] - 126s 1s/step - loss: 0.6506 - accuracy: 0.7666 - val_loss: 0.4622 - val_accuracy: 0.8264 - lr: 0.0010
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.6119 - accuracy: 0.7723
# Epoch 7: val_accuracy did not improve from 0.82870
# 110/110 [==============================] - 126s 1s/step - loss: 0.6119 - accuracy: 0.7723 - val_loss: 0.5172 - val_accuracy: 0.8056 - lr: 0.0010
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.5660 - accuracy: 0.7968
# Epoch 8: val_accuracy improved from 0.82870 to 0.85069, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 125s 1s/step - loss: 0.5660 - accuracy: 0.7968 - val_loss: 0.4317 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.5510 - accuracy: 0.7962
# Epoch 9: val_accuracy improved from 0.85069 to 0.85764, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 125s 1s/step - loss: 0.5510 - accuracy: 0.7962 - val_loss: 0.4148 - val_accuracy: 0.8576 - lr: 0.0010
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.5449 - accuracy: 0.8090
# Epoch 10: val_accuracy did not improve from 0.85764
# 110/110 [==============================] - 125s 1s/step - loss: 0.5449 - accuracy: 0.8090 - val_loss: 0.4390 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 11/30
# 110/110 [==============================] - ETA: 0s - loss: 0.5123 - accuracy: 0.8127
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_accuracy did not improve from 0.85764
# 110/110 [==============================] - 123s 1s/step - loss: 0.5123 - accuracy: 0.8127 - val_loss: 0.4027 - val_accuracy: 0.8553 - lr: 0.0010
# Epoch 12/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4310 - accuracy: 0.8355
# Epoch 12: val_accuracy improved from 0.85764 to 0.87500, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] -
# Epoch 27/30
# 110/110 [==============================] - ETA: 0s - loss: 0.3021 - accuracy: 0.8876
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 27: val_accuracy did not improve from 0.90741
# 110/110 [==============================] - 121s 1s/step - loss: 0.3021 - accuracy: 0.8876 - val_loss: 0.2926 - val_accuracy: 0.8958 - lr: 6.2500e-05
# Epoch 28/30
# 110/110 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8952
# Epoch 28: val_accuracy improved from 0.90741 to 0.90972, saving model to Models_training\RestNet50\Freeze_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 121s 1s/step - loss: 0.3005 - accuracy: 0.8952 - val_loss: 0.2571 - val_accuracy: 0.9097 - lr: 3.1250e-05
# Epoch 29/30
# 110/110 [==============================] - ETA: 0s - loss: 0.3045 - accuracy: 0.8870
# Epoch 29: val_accuracy did not improve from 0.90972
# 110/110 [==============================] - 119s 1s/step - loss: 0.3045 - accuracy: 0.8870 - val_loss: 0.2626 - val_accuracy: 0.9074 - lr: 3.1250e-05
# Epoch 30/30
# 110/110 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8901
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 30: val_accuracy did not improve from 0.90972
# 110/110 [==============================] - 120s 1s/step - loss: 0.3023 - accuracy: 0.8901 - val_loss: 0.2807 - val_accuracy: 0.9039 - lr: 3.1250e-05

# %%
print("Durée de l'entraînement:",time_callback.logs[0]//60,"minutes.")
# Out:
# Durée de l'entraînement: 61.0 minutes.

# %%
# Historique d'entrainement du modéle
training_history = pd.read_csv(csvlogger_filepath,index_col = 'epoch')
training_history.head()
# Out:
#        accuracy      loss     lr  val_accuracy  val_loss
# epoch
# 0      0.356960  1.910919  0.001      0.635417  1.106900
# 1      0.622545  1.108359  0.001      0.762731  0.713808
# 2      0.697694  0.868138  0.001      0.795139  0.567319
# 3      0.730999  0.750363  0.001      0.802083  0.571759
# 4      0.755764  0.687656  0.001      0.828704  0.506675

# %%
# Visualisation de la convergence de la fonction de perte et de l'accuracy au long de l'entraînement

def plot_history():
    training_history = pd.read_csv(csvlogger_filepath,index_col = 'epoch')
    fig, ax = plt.subplots(1, 2, figsize=(14,6))
    ax[0].plot(training_history['accuracy'], color='forestgreen')
    ax[0].plot(training_history['val_accuracy'], color='lawngreen')
    ax[0].set_title("Evolution de la précision en fonction de l'epoch")
    ax[0].set_xlabel("Epoch")
    ax[0].set_ylabel("Accuracy")
    ax[0].legend(['train', 'validation'], loc='best');
    ax[1].plot(training_history['loss'], color='forestgreen')
    ax[1].plot(training_history['val_loss'], color='lawngreen')
    ax[1].set_title("Evolution du coût en fonction de l'epoch")
    ax[1].set_xlabel("Epoch")
    ax[1].set_ylabel("Loss")
    ax[1].legend(['train', 'validation'], loc='best');
    
plot_history()

# %% [markdown]
# #### Etape 2: Fine-tuning du modèle par de-freezes successifs du modèle de base et ajustement du learning rate

# %% [markdown]
# #### Etape 2: Fine-tuning du modèle par de-freezes successifs du modèle de base et ajustement du learning rate

# %%
# Identification des couches à dé-freezer

for i,layer in enumerate(base_model.layers):
    print(i,layer.name,"Trainable:",layer.trainable)
# Out:
# 0 input_1 Trainable: False
# 1 conv1_pad Trainable: False
# 2 conv1_conv Trainable: False
# 3 conv1_bn Trainable: False
# 4 conv1_relu Trainable: False
# 5 pool1_pad Trainable: False
# 6 pool1_pool Trainable: False
# 7 conv2_block1_1_conv Trainable: False
# 8 conv2_block1_1_bn Trainable: False
# 9 conv2_block1_1_relu Trainable: False
# 10 conv2_block1_2_conv Trainable: False
# 11 conv2_block1_2_bn Trainable: False
# 12 conv2_block1_2_relu Trainable: False
# 13 conv2_block1_0_conv Trainable: False
# 14 conv2_block1_3_conv Trainable: False
# 15 conv2_block1_0_bn Trainable: False
# 87 conv4_block1_0_conv Trainable: False
# 88 conv4_block1_3_conv Trainable: False
# 89 conv4_block1_0_bn Trainable: False
# 90 conv4_block1_3_bn Trainable: False
# 91 conv4_block1_add Trainable: False
# 92 conv4_block1_out Trainable: False
# 93 conv4_block2_1_conv Trainable: False
# 94 conv4_block2_1_bn Trainable: False
# 95 conv4_block2_1_relu Trainable: False
# 96 conv4_block2_2_conv Trainable: False
# 97 conv4_block2_2_bn Trainable: False
# 98 conv4_block2_2_relu Trainable: False
# 99 conv4_block2_3_conv Trainable: False
# 100 conv4_block2_3_bn Trainable: False
# 101 conv4_block2_add Trainable: False
# 102 conv4_block2_out Trainable: False
# 103 conv4_block3_1_conv Trainable: False
# 104 conv4_block3_1_bn Trainable: False
# 105 conv4_block3_1_relu Trainable: False
# 106 conv4_block3_2_conv Trainable: False
# 107 conv4_block3_2_bn Trainable: False
# 108 conv4_block3_2_relu Trainable: False
# 109 conv4_block3_3_conv Trainable: False
# 110 conv4_block3_3_bn Trainable: False
# 111 conv4_block3_add Trainable: False
# 112 conv4_block3_out Trainable: False
# 113 conv4_block4_1_conv Trainable: False
# 114 conv4_block4_1_bn Trainable: False
# 115 conv4_block4_1_relu Trainable: False
# 116 conv4_block4_2_conv Trainable: False
# 117 conv4_block4_2_bn Trainable: False
# 118 conv4_block4_2_relu Trainable: False
# 119 conv4_block4_3_conv Trainable: False
# 120 conv4_block4_3_bn Trainable: False
# 121 conv4_block4_add Trainable: False
# 122 conv4_block4_out Trainable: False
# 123 conv4_block5_1_conv Trainable: False
# 124 conv4_block5_1_bn Trainable: False
# 125 conv4_block5_1_relu Trainable: False
# 126 conv4_block5_2_conv Trainable: False
# 127 conv4_block5_2_bn Trainable: False
# 128 conv4_block5_2_relu Trainable: False
# 129 conv4_block5_3_conv Trainable: False
# 130 conv4_block5_3_bn Trainable: False
# 131 conv4_block5_add Trainable: False
# 132 conv4_block5_out Trainable: False
# 133 conv4_block6_1_conv Trainable: False
# 134 conv4_block6_1_bn Trainable: False
# 135 conv4_block6_1_relu Trainable: False
# 136 conv4_block6_2_conv Trainable: False
# 137 conv4_block6_2_bn Trainable: False
# 138 conv4_block6_2_relu Trainable: False
# 139 conv4_block6_3_conv Trainable: False
# 140 conv4_block6_3_bn Trainable: False
# 141 conv4_block6_add Trainable: False
# 142 conv4_block6_out Trainable: False
# 143 conv5_block1_1_conv Trainable: False
# 144 conv5_block1_1_bn Trainable: False
# 145 conv5_block1_1_relu Trainable: False
# 146 conv5_block1_2_conv Trainable: False
# 147 conv5_block1_2_bn Trainable: False
# 148 conv5_block1_2_relu Trainable: False
# 149 conv5_block1_0_conv Trainable: False
# 150 conv5_block1_3_conv Trainable: False
# 151 conv5_block1_0_bn Trainable: False
# 152 conv5_block1_3_bn Trainable: False
# 153 conv5_block1_add Trainable: False
# 154 conv5_block1_out Trainable: False
# 155 conv5_block2_1_conv Trainable: False
# 156 conv5_block2_1_bn Trainable: False
# 157 conv5_block2_1_relu Trainable: False
# 158 conv5_block2_2_conv Trainable: False
# 159 conv5_block2_2_bn Trainable: False
# 160 conv5_block2_2_relu Trainable: False
# 161 conv5_block2_3_conv Trainable: False
# 162 conv5_block2_3_bn Trainable: False
# 163 conv5_block2_add Trainable: False
# 164 conv5_block2_out Trainable: False
# 165 conv5_block3_1_conv Trainable: False
# 166 conv5_block3_1_bn Trainable: False
# 167 conv5_block3_1_relu Trainable: False
# 168 conv5_block3_2_conv Trainable: False
# 169 conv5_block3_2_bn Trainable: False
# 170 conv5_block3_2_relu Trainable: False
# 171 conv5_block3_3_conv Trainable: False
# 172 conv5_block3_3_bn Trainable: False
# 173 conv5_block3_add Trainable: False
# 174 conv5_block3_out Trainable: False
# 175 avg_pool Trainable: False

# %%
for layer in base_model.layers[143:]:
    layer.trainable = True

# %%
# Définition des paramètres d'entraînement
checkpoint_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_1','best_weights.ckpt')
csvlogger_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_1','training_history.csv')
loadweights_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','Freeze','best_weights.ckpt')
lr=1.e-4
nb_epochs=30

# %%
# Lancement de l'entraînement
model_load_and_fit(checkpoint_filepath,csvlogger_filepath,loadweights_filepath=loadweights_filepath,lr=lr,nb_epochs=nb_epochs)
# Out:
# Loading model weights
# Compiling model
# Model compilation OK, learning rate = 1e-04
# Launching training
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.8491
# Epoch 1: val_accuracy improved from -inf to 0.85880, saving model to Models_training\RestNet50\no_Freeze_143_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 142s 1s/step - loss: 0.4578 - accuracy: 0.8491 - val_loss: 0.4915 - val_accuracy: 0.8588 - lr: 1.0000e-04
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.8975
# Epoch 2: val_accuracy improved from 0.85880 to 0.90278, saving model to Models_training\RestNet50\no_Freeze_143_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 140s 1s/step - loss: 0.2795 - accuracy: 0.8975 - val_loss: 0.3108 - val_accuracy: 0.9028 - lr: 1.0000e-04
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.2529 - accuracy: 0.9098
# Epoch 3: val_accuracy improved from 0.90278 to 0.90856, saving model to Models_training\RestNet50\no_Freeze_143_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 140s 1s/step - loss: 0.2529 - accuracy: 0.9098 - val_loss: 0.2951 - val_accuracy: 0.9086 - lr: 1.0000e-04
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1959 - accuracy: 0.9308
# Epoch 4: val_accuracy improved from 0.90856 to 0.92361, saving model to Models_training\RestNet50\no_Freeze_143_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 140s 1s/step - loss: 0.1959 - accuracy: 0.9308 - val_loss: 0.2373 - val_accuracy: 0.9236 - lr: 1.0000e-04
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1891 - accuracy: 0.9308
# Epoch 5: val_accuracy improved from 0.92361 to 0.93519, saving model to Models_training\RestNet50\no_Freeze_143_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 140s 1s/step - loss: 0.1891 - accuracy: 0.9308 - val_loss: 0.2231 - val_accuracy: 0.9352 - lr: 1.0000e-04
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1703 - accuracy: 0.9405
# Epoch 6: val_accuracy did not improve from 0.93519
# 110/110 [==============================] - 140s 1s/step - loss: 0.1703 - accuracy: 0.9405 - val_loss: 0.2085 - val_accuracy: 0.9352 - lr: 1.0000e-04
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9479
# Epoch 7: val_accuracy did not improve from 0.93519
# 110/110 [==============================] - 138s 1s/step - loss: 0.1352 - accuracy: 0.9479 - val_loss: 0.2431 - val_accuracy: 0.9317 - lr: 1.0000e-04
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9431
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 8: val_accuracy did not improve from 0.93519
# 110/110 [==============================] - 139s 1s/step - loss: 0.1464 - accuracy: 0.9431 - val_loss: 0.2349 - val_accuracy: 0.9213 - lr: 1.0000e-04
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9556
# Epoch 9: val_accuracy did not improve from 0.93519
# 110/110 [==============================] - 140s 1s/step - loss: 0.1266 - accuracy: 0.9556 - val_loss: 0.1939 - val_accuracy: 0.9340 - lr: 5.0000e-05
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9627
# Epoch 10: val_accuracy improved from 0.93519 to 0.93634, saving model to Models_training\RestNet50\no_Freeze_143_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 139s 1s/step - loss: 0.1014 - accuracy: 0.9627 - val_loss: 0.1877 - val_accuracy: 0.9363 - lr: 5.0000e-05
# Epoch 11/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9670
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 11: val_accuracy improved from 0.93634 to 0.93866, saving model to Models_training\RestNet50\no_Freeze_143_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 141s 1s/step - loss: 0.0862 - accuracy: 0.9670 - val_loss: 0.1942 - val_accuracy: 0.9387 - lr: 5.0000e-05
# Epoch 12/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9712
# Epoch 12: val_accuracy improved from 0.93866 to 0.94676, saving model to Models_training\RestNet50\no_Freeze_143_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 140s 1s/step - loss: 0.0900 - accuracy: 0.9712 - val_loss: 0.1931 - val_accuracy: 0.9468 - lr: 2.5000e-05
# Epoch 13/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.
# Epoch 29/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9861
# Epoch 29: val_accuracy did not improve from 0.96181
# 110/110 [==============================] - 140s 1s/step - loss: 0.0403 - accuracy: 0.9861 - val_loss: 0.2041 - val_accuracy: 0.9433 - lr: 1.5625e-06
# Epoch 30/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9872
# Epoch 30: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
#
# Epoch 30: val_accuracy did not improve from 0.96181
# 110/110 [==============================] - 138s 1s/step - loss: 0.0465 - accuracy: 0.9872 - val_loss: 0.1925 - val_accuracy: 0.9537 - lr: 1.5625e-06

# %%
print("Durée de l'entraînement:",time_callback.logs[-1]//60,"minutes.")
# Out:
# Durée de l'entraînement: 69.0 minutes.

# %%
# Historique d'entrainement du modéle
training_history = pd.read_csv(csvlogger_filepath,index_col = 'epoch')
training_history.head()
# Out:
#        accuracy      loss      lr  val_accuracy  val_loss
# epoch
# 0      0.849132  0.457810  0.0001      0.858796  0.491505
# 1      0.897523  0.279489  0.0001      0.902778  0.310795
# 2      0.909764  0.252935  0.0001      0.908565  0.295101
# 3      0.930828  0.195933  0.0001      0.923611  0.237315
# 4      0.930828  0.189123  0.0001      0.935185  0.223060

# %%
# Visualisation de la convergence de la fonction de perte et de l'accuracy au long de l'entraînement
plot_history()

# %% [markdown]
# #### Etape 2.2: De-freeze du 4ème bloc du modèle de base

# %%
# De_freeze le 2eme blocs
for layer in base_model.layers[81:]:
    layer.trainable = True

# %%
# Définition des paramètres d'entraînement
checkpoint_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_2','best_weights.ckpt')
csvlogger_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_2','training_history.csv')
loadweights_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_1','best_weights.ckpt')
lr=1.e-4
nb_epochs=30

# %%
# Lancement de l'entraînement
model_load_and_fit(checkpoint_filepath,csvlogger_filepath,loadweights_filepath=loadweights_filepath,lr=lr,nb_epochs=nb_epochs)
# Out:
# Loading model weights
# Compiling model
# Model compilation OK, learning rate = 1e-04
# Launching training
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 0.2123 - accuracy: 0.9291
# Epoch 1: val_accuracy improved from -inf to 0.90625, saving model to Models_training\RestNet50\no_Freeze_81_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 248s 2s/step - loss: 0.2123 - accuracy: 0.9291 - val_loss: 0.3471 - val_accuracy: 0.9062 - lr: 1.0000e-04
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9465
# Epoch 2: val_accuracy did not improve from 0.90625
# 110/110 [==============================] - 237s 2s/step - loss: 0.1565 - accuracy: 0.9465 - val_loss: 0.5533 - val_accuracy: 0.8796 - lr: 1.0000e-04
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9471
# Epoch 3: val_accuracy improved from 0.90625 to 0.93519, saving model to Models_training\RestNet50\no_Freeze_81_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 246s 2s/step - loss: 0.1792 - accuracy: 0.9471 - val_loss: 0.2430 - val_accuracy: 0.9352 - lr: 1.0000e-04
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9607
# Epoch 4: val_accuracy did not improve from 0.93519
# 110/110 [==============================] - 249s 2s/step - loss: 0.1241 - accuracy: 0.9607 - val_loss: 0.2819 - val_accuracy: 0.9282 - lr: 1.0000e-04
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9590
# Epoch 5: val_accuracy improved from 0.93519 to 0.94097, saving model to Models_training\RestNet50\no_Freeze_81_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 241s 2s/step - loss: 0.1165 - accuracy: 0.9590 - val_loss: 0.2020 - val_accuracy: 0.9410 - lr: 1.0000e-04
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9579
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 6: val_accuracy did not improve from 0.94097
# 110/110 [==============================] - 246s 2s/step - loss: 0.1272 - accuracy: 0.9579 - val_loss: 0.3271 - val_accuracy: 0.9190 - lr: 1.0000e-04
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9693
# Epoch 7: val_accuracy improved from 0.94097 to 0.94676, saving model to Models_training\RestNet50\no_Freeze_81_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 248s 2s/step - loss: 0.0886 - accuracy: 0.9693 - val_loss: 0.2157 - val_accuracy: 0.9468 - lr: 5.0000e-05
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9798
# Epoch 8: val_accuracy improved from 0.94676 to 0.95370, saving model to Models_training\RestNet50\no_Freeze_81_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 244s 2s/step - loss: 0.0615 - accuracy: 0.9798 - val_loss: 0.1946 - val_accuracy: 0.9537 - lr: 5.0000e-05
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9801
# Epoch 9: val_accuracy did not improve from 0.95370
# 110/110 [==============================] - 245s 2s/step - loss: 0.0503 - accuracy: 0.9801 - val_loss: 0.1789 - val_accuracy: 0.9537 - lr: 5.0000e-05
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.
0 minutes.

# %%
# Historique d'entrainement du modéle
training_history = pd.read_csv(csvlogger_filepath,index_col = 'epoch')
training_history.head()
# Out:
#        accuracy      loss      lr  val_accuracy  val_loss
# epoch
# 0      0.929120  0.212348  0.0001      0.906250  0.347122
# 1      0.946485  0.156548  0.0001      0.879630  0.553292
# 2      0.947054  0.179211  0.0001      0.935185  0.243042
# 3      0.960717  0.124108  0.0001      0.928241  0.281919
# 4      0.959009  0.116548  0.0001      0.940972  0.202041

# %%
# Visualisation de la convergence de la fonction de perte et de l'accuracy au long de l'entraînement
plot_history()

# %% [markdown]
# #### Etape 2.3: De-freeze du 3ème bloc du modèle de base

# %%
# De_freeze le 3eme blocs
for layer in base_model.layers[39:]:
    layer.trainable = True

# %%
# Définition des paramètres d'entraînement
checkpoint_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_3','best_weights.ckpt')
csvlogger_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_3','training_history.csv')
loadweights_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','Un_Freeze_2','best_weights.ckpt')
lr=1.e-5
nb_epochs=30

# %%
# Lancement de l'entraînement
model_load_and_fit(checkpoint_filepath,csvlogger_filepath,loadweights_filepath=loadweights_filepath,lr=lr,nb_epochs=nb_epochs)
# Out:
# Loading model weights
# Compiling model
# Model compilation OK, learning rate = 1e-05
# Launching training
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9909
# Epoch 1: val_accuracy improved from -inf to 0.95370, saving model to Models_training\RestNet50\no_Freeze_39_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 372s 3s/step - loss: 0.0275 - accuracy: 0.9909 - val_loss: 0.2516 - val_accuracy: 0.9537 - lr: 1.0000e-05
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9912
# Epoch 2: val_accuracy did not improve from 0.95370
# 110/110 [==============================] - 366s 3s/step - loss: 0.0232 - accuracy: 0.9912 - val_loss: 0.2434 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9929
# Epoch 3: val_accuracy did not improve from 0.95370
# 110/110 [==============================] - 357s 3s/step - loss: 0.0234 - accuracy: 0.9929 - val_loss: 0.2108 - val_accuracy: 0.9525 - lr: 1.0000e-05
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9949
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 4: val_accuracy improved from 0.95370 to 0.95949, saving model to Models_training\RestNet50\no_Freeze_39_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 386s 4s/step - loss: 0.0138 - accuracy: 0.9949 - val_loss: 0.2006 - val_accuracy: 0.9595 - lr: 1.0000e-05
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9943
# Epoch 5: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 389s 4s/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.1951 - val_accuracy: 0.9525 - lr: 5.0000e-06
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9937
# Epoch 6: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 361s 3s/step - loss: 0.0209 - accuracy: 0.9937 - val_loss: 0.2177 - val_accuracy: 0.9560 - lr: 5.0000e-06
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9946
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 7: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 418s 4s/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.2150 - val_accuracy: 0.9572 - lr: 5.0000e-06
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9937
# Epoch 8: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 380s 3s/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.2222 - val_accuracy: 0.9560 - lr: 2.5000e-06
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9952
# Epoch 9: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 366s 3s/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.2168 - val_accuracy: 0.9537 - lr: 2.5000e-06
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9960
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 10: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 381s 3s/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.2106 - val_accuracy: 0.9549 - lr: 2.5000e-06
# Epoch 11/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9935
# Epoch 11: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 369s 3s/step - loss: 0.0162 - accuracy: 0.9935 - val_loss: 0.1991 - val_accuracy: 0.9572 - lr: 1.2500e-06
# Epoch 12/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9969
# Epoch 12: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 375s 3s/step - loss: 0.0119 - accuracy: 0.9969 - val_loss: 0.1922 - val_accuracy: 0.9595 - lr: 1.2500e-06
# Epoch 13/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9937
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 13: val_accuracy improved from 0.95949 to 0.96065, saving model to Models_training\RestNet50\no_Freeze_39_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 381s 3s/step - loss: 0.0145 - accuracy: 0.9937 - val_loss: 0.1966 - val_accuracy: 0.9606 - lr: 1.2500e-06
# Epoch 14/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9963
# Epoch 14: val_accuracy improved from 0.96065 to 0.96181, saving model to Models_training\RestNet50\no_Freeze_39_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 384s 3s/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.2032 - val_accuracy: 0.9618 - lr: 6.2500e-07
# Epoch 15/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9969
# Epoch 15: val_accuracy did not improve from 0.96181
# 110/110 [==============================] - 377s 3s/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.2142 - val_accuracy: 0.9549 - lr: 6.2500e-07
# Epoch 16/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9969
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 16: val_accuracy did not improve from 0.96181
# 110/110 [==============================] - 378s 3s/step - loss: 0.0158 - accuracy: 0.9969 - val_loss: 0.2086 - val_accuracy: 0.9595 - lr: 6.2500e-07
# Epoch 17/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9963
# Epoch 17: val_accuracy did not improve from 0.96181
# 110/110 [==============================] - 387s 4s/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.1994 - val_accuracy: 0.9549 - lr: 3.1250e-07
# Epoch 18/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9946
# Epoch 18: val_accuracy improved from 0.96181 to 0.96412, saving model to Models_training\RestNet50\no_Freeze_39_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 377s 3s/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.1753 - val_accuracy: 0.9641 - lr: 3.1250e-07
# Epoch 19/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9954
# Epoch 19: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 376s 3s/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 0.2112 - val_accuracy: 0.9618 - lr: 3.1250e-07
# Epoch 20/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9952
# Epoch 20: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 374s 3s/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.2112 - val_accuracy: 0.9595 - lr: 3.1250e-07
# Epoch 21/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9977
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 21: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 377s 3s/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.2262 - val_accuracy: 0.9606 - lr: 3.1250e-07
# Epoch 22/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9969
# Epoch 22: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 381s 3s/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.2122 - val_accuracy: 0.9606 - lr: 1.5625e-07
# Epoch 23/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9963
# Epoch 23: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 381s 3s/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.2142 - val_accuracy: 0.9572 - lr: 1.5625e-07
# Epoch 24/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9966
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-08.
#
# Epoch 24: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 377s 3s/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.2061 - val_accuracy: 0.9583 - lr: 1.5625e-07
# Epoch 25/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9963
# Epoch 25: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 379s 3s/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.2260 - val_accuracy: 0.9560 - lr: 7.8125e-08
# Epoch 26/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9954
# Epoch 26: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 382s 3s/step - loss: 0.0125 - accuracy: 0.9954 - val_loss: 0.2171 - val_accuracy: 0.9618 - lr: 7.8125e-08
# Epoch 27/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9972
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-08.
#
# Epoch 27: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 364s 3s/step - loss: 0.0163 - accuracy: 0.9972 - val_loss: 0.2136 - val_accuracy: 0.9525 - lr: 7.8125e-08
# Epoch 28/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9966
# Epoch 28: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 377s 3s/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.2083 - val_accuracy: 0.9595 - lr: 3.9062e-08
# Epoch 29/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9946
# Epoch 29: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 379s 3s/step - loss: 0.0144 - accuracy: 0.9946 - val_loss: 0.1958 - val_accuracy: 0.9606 - lr: 3.9062e-08
# Epoch 30/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9966
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-08.
#
# Epoch 30: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 377s 3s/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.2322 - val_accuracy: 0.9560 - lr: 3.9062e-08

# %%
print("Durée de l'entraînement:",time_callback.logs[-1]//60,"minutes.")
# Out:
# Durée de l'entraînement: 188.0 minutes.

# %%
# Historique d'entrainement du modéle
training_history = pd.read_csv(csvlogger_filepath,index_col = 'epoch')
training_history.head()
# Out:
#        accuracy      loss        lr  val_accuracy  val_loss
# epoch
# 0      0.990891  0.027511  0.000010      0.953704  0.251596
# 1      0.991176  0.023192  0.000010      0.951389  0.243448
# 2      0.992884  0.023437  0.000010      0.952546  0.210816
# 3      0.994876  0.013787  0.000010      0.959491  0.200624
# 4      0.994307  0.016347  0.000005      0.952546  0.195097

# %%
# Visualisation de la convergence de la fonction de perte et de l'accuracy au long de l'entraînement
plot_history()

# %% [markdown]
# ##### Etape 2.4: De-freeze du 2 ème bloc du modèle de base

# %%
for layer in base_model.layers[7:]:
    layer.trainable = True

# %%
# Définition des paramètres d'entraînement
checkpoint_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_4','best_weights.ckpt')
csvlogger_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_4','training_history.csv')
loadweights_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_3','best_weights.ckpt')
lr=1.e-5
nb_epochs=30

# %%
# Lancement de l'entraînement
model_load_and_fit(checkpoint_filepath,csvlogger_filepath,loadweights_filepath=loadweights_filepath,lr=lr,nb_epochs=nb_epochs)
# Out:
# Loading model weights
# Compiling model
# Model compilation OK, learning rate = 1e-05
# Launching training
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9937
# Epoch 1: val_accuracy improved from -inf to 0.93750, saving model to Models_training\RestNet50\no_Freeze_7_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 517s 5s/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.3135 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9906
# Epoch 2: val_accuracy improved from 0.93750 to 0.95139, saving model to Models_training\RestNet50\no_Freeze_7_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 496s 5s/step - loss: 0.0241 - accuracy: 0.9906 - val_loss: 0.2311 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9920
# Epoch 3: val_accuracy improved from 0.95139 to 0.95949, saving model to Models_training\RestNet50\no_Freeze_7_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 511s 5s/step - loss: 0.0206 - accuracy: 0.9920 - val_loss: 0.1920 - val_accuracy: 0.9595 - lr: 1.0000e-05
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9935
# Epoch 4: val_accuracy did not improve from 0.95949
# 110/110 [==============================] - 485s 4s/step - loss: 0.0222 - accuracy: 0.9935 - val_loss: 0.2188 - val_accuracy: 0.9572 - lr: 1.0000e-05
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9983
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 5: val_accuracy improved from 0.95949 to 0.96065, saving model to Models_training\RestNet50\no_Freeze_7_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 488s 4s/step - loss: 0.0094 - accuracy: 0.9983 - val_loss: 0.2153 - val_accuracy: 0.9606 - lr: 1.0000e-05
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9957
# Epoch 6: val_accuracy did not improve from 0.96065
# 110/110 [==============================] - 487s 4s/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.2225 - val_accuracy: 0.9549 - lr: 5.0000e-06
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9954
# Epoch 7: val_accuracy did not improve from 0.96065
# 110/110 [==============================] - 502s 5s/step - loss: 0.0150 - accuracy: 0.9954 - val_loss: 0.2141 - val_accuracy: 0.9525 - lr: 5.0000e-06
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9960
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 8: val_accuracy did not improve from 0.96065
# 110/110 [==============================] - 490s 4s/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.2287 - val_accuracy: 0.9572 - lr: 5.0000e-06
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9974
# Epoch 9: val_accuracy improved from 0.96065 to 0.96296, saving model to Models_training\RestNet50\no_Freeze_7_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 506s 5s/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.1869 - val_accuracy: 0.9630 - lr: 2.5000e-06
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9946
# Epoch 10: val_accuracy did not improve from 0.96296
# 110/110 [==============================] - 487s 4s/step - loss: 0.0140 - accuracy: 0.9946 - val_loss: 0.2422 - val_accuracy: 0.9595 - lr: 2.5000e-06
# Epoch 11/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9977
# Epoch 11: val_accuracy did not improve from 0.96296
# 110/110 [==============================] - 499s 5s/step - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.2345 - val_accuracy: 0.9560 - lr: 2.5000e-06
# Epoch 12/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9963
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 12: val_accuracy did not improve from 0.96296
# 110/110 [==============================] - 509s 5s/step - loss: 0.0162 - accuracy: 0.9963 - val_loss: 0.2478 - val_accuracy: 0.9502 - lr: 2.5000e-06
# Epoch 13/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9963
# Epoch 13: val_accuracy did not improve from 0.96296
# 110/110 [==============================] - 507s 5s/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.2096 - val_accuracy: 0.9630 - lr: 1.2500e-06
# Epoch 14/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9972
# Epoch 14: val_accuracy did not improve from 0.96296
# 110/110 [==============================] - 486s 4s/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 0.2384 - val_accuracy: 0.9560 - lr: 1.2500e-06
# Epoch 15/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9960
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 15: val_accuracy did not improve from 0.96296
# 110/110 [==============================] - 484s 4s/step - loss: 0.0097 - accuracy: 0.9960 - val_loss: 0.2431 - val_accuracy: 0.9537 - lr: 1.2500e-06
# Epoch 16/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9986
# Epoch 16: val_accuracy improved from 0.96296 to 0.96412, saving model to Models_training\RestNet50\no_Freeze_7_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 478s 4s/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.1873 - val_accuracy: 0.9641 - lr: 6.2500e-07
# Epoch 17/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9980
# Epoch 17: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 484s 4s/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.1992 - val_accuracy: 0.9630 - lr: 6.2500e-07
# Epoch 18/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9954
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 18: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 518s 5s/step - loss: 0.0103 - accuracy: 0.9954 - val_loss: 0.2280 - val_accuracy: 0.9560 - lr: 6.2500e-07
# Epoch 19/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9960
# Epoch 19: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 502s 5s/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.2095 - val_accuracy: 0.9630 - lr: 3.1250e-07
# Epoch 20/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9960
# Epoch 20: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 497s 5s/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.2367 - val_accuracy: 0.9583 - lr: 3.1250e-07
# Epoch 21/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9980
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 21: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 505s 5s/step - loss: 0.0084 - accuracy: 0.9980 - val_loss: 0.1987 - val_accuracy: 0.9618 - lr: 3.1250e-07
# Epoch 22/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9972
# Epoch 22: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 528s 5s/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 0.2064 - val_accuracy: 0.9606 - lr: 1.5625e-07
# Epoch 23/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9980
# Epoch 23: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 517s 5s/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.2070 - val_accuracy: 0.9560 - lr: 1.5625e-07
# Epoch 24/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9977
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-08.
#
# Epoch 24: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 499s 5s/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.2209 - val_accuracy: 0.9537 - lr: 1.5625e-07
# Epoch 25/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9983
# Epoch 25: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 486s 4s/step - loss: 0.0086 - accuracy: 0.9983 - val_loss: 0.2160 - val_accuracy: 0.9560 - lr: 7.8125e-08
# Epoch 26/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9966
# Epoch 26: val_accuracy improved from 0.96412 to 0.96528, saving model to Models_training\RestNet50\no_Freeze_7_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 498s 5s/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.1706 - val_accuracy: 0.9653 - lr: 7.8125e-08
# Epoch 27/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9966
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-08.
#
# Epoch 27: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 499s 5s/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.1978 - val_accuracy: 0.9641 - lr: 7.8125e-08
# Epoch 28/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9989
# Epoch 28: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 497s 5s/step - loss: 0.0057 - accuracy: 0.9989 - val_loss: 0.2182 - val_accuracy: 0.9525 - lr: 3.9062e-08
# Epoch 29/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9974
# Epoch 29: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 503s 5s/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.2120 - val_accuracy: 0.9606 - lr: 3.9062e-08
# Epoch 30/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9986
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-08.
#
# Epoch 30: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 492s 4s/step - loss: 0.0094 - accuracy: 0.9986 - val_loss: 0.2040 - val_accuracy: 0.9595 - lr: 3.9062e-08

# %%
print("Durée de l'entraînement:",time_callback.logs[-1]//60,"minutes.")
# Out:
# Durée de l'entraînement: 249.0 minutes.

# %%
# Historique d'entrainement du modéle
training_history = pd.read_csv(csvlogger_filepath,index_col = 'epoch')
training_history.head()
# Out:
#        accuracy      loss       lr  val_accuracy  val_loss
# epoch
# 0      0.993738  0.018921  0.00001      0.937500  0.313532
# 1      0.990606  0.024150  0.00001      0.951389  0.231133
# 2      0.992030  0.020624  0.00001      0.959491  0.191952
# 3      0.993453  0.022201  0.00001      0.957176  0.218833
# 4      0.998292  0.009354  0.00001      0.960648  0.215257

# %%
# Visualisation de la convergence de la fonction de perte et de l'accuracy au long de l'entraînement
plot_history()

# %% [markdown]
# ##### Etape 2.5: De-freeze complet du modèle de base

# %%
for layer in base_model.layers[:]:
    layer.trainable = True

# %%
# Définition des paramètres d'entraînement
checkpoint_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_5','best_weights.ckpt')
csvlogger_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_5','training_history.csv')
loadweights_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_4','best_weights.ckpt')
lr=1.e-5
nb_epochs=30

# %%
# Lancement de l'entraînement
model_load_and_fit(checkpoint_filepath,csvlogger_filepath,loadweights_filepath=loadweights_filepath,lr=lr,nb_epochs=nb_epochs)
# Out:
# Loading model weights
# Compiling model
# Model compilation OK, learning rate = 1e-05
# Launching training
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9952
# Epoch 1: val_accuracy improved from -inf to 0.94792, saving model to Models_training\RestNet50\no_Freeze_0_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 525s 5s/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.2876 - val_accuracy: 0.9479 - lr: 1.0000e-05
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9949
# Epoch 2: val_accuracy improved from 0.94792 to 0.95255, saving model to Models_training\RestNet50\no_Freeze_0_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 528s 5s/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 0.2860 - val_accuracy: 0.9525 - lr: 1.0000e-05
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9960
# Epoch 3: val_accuracy improved from 0.95255 to 0.96412, saving model to Models_training\RestNet50\no_Freeze_0_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 529s 5s/step - loss: 0.0135 - accuracy: 0.9960 - val_loss: 0.2336 - val_accuracy: 0.9641 - lr: 1.0000e-05
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9957
# Epoch 4: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 513s 5s/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 0.2339 - val_accuracy: 0.9583 - lr: 1.0000e-05
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9969
# Epoch 5: val_accuracy did not improve from 0.96412
# 110/110 [==============================] - 514s 5s/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.2549 - val_accuracy: 0.9549 - lr: 1.0000e-05
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9957
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 6: val_accuracy improved from 0.96412 to 0.96528, saving model to Models_training\RestNet50\no_Freeze_0_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 525s 5s/step - loss: 0.0116 - accuracy: 0.9957 - val_loss: 0.2288 - val_accuracy: 0.9653 - lr: 1.0000e-05
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9966
# Epoch 7: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 508s 5s/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.1858 - val_accuracy: 0.9653 - lr: 5.0000e-06
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9974
# Epoch 8: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 512s 5s/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.2660 - val_accuracy: 0.9525 - lr: 5.0000e-06
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9963
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 9: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 514s 5s/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.2047 - val_accuracy: 0.9641 - lr: 5.0000e-06
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9963
# Epoch 10: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 515s 5s/step - loss: 0.0095 - accuracy: 0.9963 - val_loss: 0.2006 - val_accuracy: 0.9653 - lr: 2.5000e-06
# Epoch 11/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9986
# Epoch 11: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 520s 5s/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.2051 - val_accuracy: 0.9618 - lr: 2.5000e-06
# Epoch 12/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9980
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 12: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 520s 5s/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.2325 - val_accuracy: 0.9618 - lr: 2.5000e-06
# Epoch 13/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9977
# Epoch 13: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 504s 5s/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.2184 - val_accuracy: 0.9606 - lr: 1.2500e-06
# Epoch 14/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9974
# Epoch 14: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 518s 5s/step - loss: 0.0103 - accuracy: 0.9974 - val_loss: 0.1897 - val_accuracy: 0.9653 - lr: 1.2500e-06
# Epoch 15/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9980
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 15: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 537s 5s/step - loss: 0.0095 - accuracy: 0.9980 - val_loss: 0.2128 - val_accuracy: 0.9572 - lr: 1.2500e-06
# Epoch 16/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9974
# Epoch 16: val_accuracy did not improve from 0.96528
# 110/110 [==============================] - 525s 5s/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.2009 - val_accuracy: 0.9630 - lr: 6.2500e-07
# Epoch 17/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9966
# Epoch 17: val_accuracy improved from 0.96528 to 0.96644, saving model to Models_training\RestNet50\no_Freeze_0_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 518s 5s/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.1801 - val_accuracy: 0.9664 - lr: 6.2500e-07
# Epoch 18/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9977
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 18: val_accuracy did not improve from 0.96644
# 110/110 [==============================] - 512s 5s/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.2173 - val_accuracy: 0.9641 - lr: 6.2500e-07
# Epoch 19/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9980
# Epoch 19: val_accuracy did not improve from 0.96644
# 110/110 [==============================] - 506s 5s/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.2143 - val_accuracy: 0.9618 - lr: 3.1250e-07
# Epoch 20/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9983
# Epoch 20: val_accuracy did not improve from 0.96644
# 110/110 [==============================] - 501s 5s/step - loss: 0.0098 - accuracy: 0.9983 - val_loss: 0.1933 - val_accuracy: 0.9606 - lr: 3.1250e-07
# Epoch 21/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9980
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 21: val_accuracy did not improve from 0.96644
# 110/110 [==============================] - 510s 5s/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.2218 - val_accuracy: 0.9583 - lr: 3.1250e-07
# Epoch 22/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9983
# Epoch 22: val_accuracy improved from 0.96644 to 0.96875, saving model to Models_training\RestNet50\no_Freeze_0_no_zoom\best_weights.ckpt
# 110/110 [==============================] - 497s 5s/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.2067 - val_accuracy: 0.9688 - lr: 1.5625e-07
# Epoch 23/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9983
# Epoch 23: val_accuracy did not improve from 0.96875
# 110/110 [==============================] - 494s 4s/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.1826 - val_accuracy: 0.9630 - lr: 1.5625e-07
# Epoch 24/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9974
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-08.
#
# Epoch 24: val_accuracy did not improve from 0.96875
# 110/110 [==============================] - 510s 5s/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.2105 - val_accuracy: 0.9653 - lr: 1.5625e-07
# Epoch 25/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9972
# Epoch 25: val_accuracy did not improve from 0.96875
# 110/110 [==============================] - 497s 5s/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.2221 - val_accuracy: 0.9606 - lr: 7.8125e-08
# Epoch 26/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9997
# Epoch 26: val_accuracy did not improve from 0.96875
# 110/110 [==============================] - 493s 4s/step - loss: 0.0043 - accuracy: 0.9997 - val_loss: 0.2107 - val_accuracy: 0.9618 - lr: 7.8125e-08
# Epoch 27/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9977
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-08.
#
# Epoch 27: val_accuracy did not improve from 0.96875
# 110/110 [==============================] - 507s 5s/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.2146 - val_accuracy: 0.9595 - lr: 7.8125e-08
# Epoch 28/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9980
# Epoch 28: val_accuracy did not improve from 0.96875
# 110/110 [==============================] - 503s 5s/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 0.2238 - val_accuracy: 0.9595 - lr: 3.9062e-08
# Epoch 29/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9977
# Epoch 29: val_accuracy did not improve from 0.96875
# 110/110 [==============================] - 500s 5s/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.2039 - val_accuracy: 0.9572 - lr: 3.9062e-08
# Epoch 30/30
# 110/110 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9972
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-08.
#
# Epoch 30: val_accuracy did not improve from 0.96875
# 110/110 [==============================] - 509s 5s/step - loss: 0.0122 - accuracy: 0.9972 - val_loss: 0.2005 - val_accuracy: 0.9618 - lr: 3.9062e-08

# %%
print("Durée de l'entraînement:",time_callback.logs[-1]//60,"minutes.")
# Out:
# Durée de l'entraînement: 256.0 minutes.

# %%
# Historique d'entrainement du modéle
training_history = pd.read_csv(csvlogger_filepath,index_col = 'epoch')
training_history.head()
# Out:
#        accuracy      loss       lr  val_accuracy  val_loss
# epoch
# 0      0.995161  0.015423  0.00001      0.947917  0.287601
# 1      0.994876  0.016446  0.00001      0.952546  0.285953
# 2      0.996015  0.013474  0.00001      0.964120  0.233621
# 3      0.995730  0.011746  0.00001      0.958333  0.233949
# 4      0.996869  0.009809  0.00001      0.954861  0.254875

# %%
# Visualisation de la convergence de la fonction de perte et de l'accuracy au long de l'entraînement
plot_history()

# %% [markdown]
# #### Sauvegarde du modèle final (intégralement de-freezé et entraîné) avec les meilleurs poids

# %%
# Chargement des meilleurs poids
model.load_weights(Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_5','best_weights.ckpt'))

# %%
# Sauvegarde au format TensorFlow SavedModel
saving_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','Final_model')
model.save(saving_filepath)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Models_training\RestNet50_lowaugm_nosegmentation\Final_model\assets
# INFO:tensorflow:Assets written to: Models_training\RestNet50_lowaugm_nosegmentation\Final_model\assets

# %% [markdown]
# #### Analyse de l'entraînement

# %%
# Visualisation des courbes de convergence de la fonction de coût et de l'accuracy au long de l'entraînement 
# pour le modèle freezé, et pour le modèle intégralemet de-freezé

csvlogger_filepath_freeze = Path('Models_training','RestNet50_lowaugm_nosegmentation','Freeze','training_history.csv')
csvlogger_filepath_unfreeze = Path('Models_training','RestNet50_lowaugm_nosegmentation','UnFreeze_5','training_history.csv')


training_history_freeze = pd.read_csv(csvlogger_filepath_freeze,index_col = 'epoch')
training_history_unfreeze = pd.read_csv(csvlogger_filepath_unfreeze,index_col = 'epoch')
    
fig, ax = plt.subplots(1, 2, figsize=(14,6))
ax[0].plot(training_history_freeze['accuracy'],linestyle='-.',color='forestgreen',label="Freezed model-train")
ax[0].plot(training_history_freeze['val_accuracy'],linestyle='-.',color='lawngreen',label="Freezed model-validation")
ax[0].plot(training_history_unfreeze['accuracy'], color='forestgreen',label="Unfreezed model-train")
ax[0].plot(training_history_unfreeze['val_accuracy'], color='lawngreen',label="Unfreezed model-validation")
ax[0].set_title("Evolution de la précision en fonction de l'epoch")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Accuracy")
ax[0].legend(loc='best');
ax[1].plot(training_history_freeze['loss'],linestyle='-.',color='forestgreen',label="Freezed model-train")
ax[1].plot(training_history_freeze['val_loss'],linestyle='-.',color='lawngreen',label="Freezed model-validation")
ax[1].plot(training_history_unfreeze['loss'],color='forestgreen',label="Unfreezed model-train")
ax[1].plot(training_history_unfreeze['val_loss'],color='lawngreen',label="Unfreezed model-validation")
ax[1].set_title("Evolution du coût en fonction de l'epoch")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss")
ax[1].legend(loc='best');

# %%
# Visualisation des courbes de dé-freezage

# Récupération des valeurs de loss et accuracy pour le modèle freezé et les de-freezes successifs
loss=[]
accuracy=[]
val_loss=[]
val_accuracy=[]

# Modèle freezé
loadweights_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation','Freeze','best_weights.ckpt')
print("Loading model weights - Freeze")
model.load_weights(loadweights_filepath)
print("Compiling model")
model.compile(optimizer=Adam(learning_rate=lr),loss='sparse_categorical_crossentropy',metrics='accuracy')
print("Evaluating model")
train_res = model.evaluate(train_iterator)
loss.append(train_res[0])
accuracy.append(train_res[1])
val_res = model.evaluate(validation_iterator)
val_loss.append(val_res[0])
val_accuracy.append(val_res[1])

# De-freezes successifs
nb_defreeze = 5
for k in range(nb_defreeze):
    directory = "UnFreeze_"+str(k+1)
    loadweights_filepath = Path('Models_training','RestNet50_lowaugm_nosegmentation',directory,'best_weights.ckpt')
    print("Loading model weights - Unfreeze",str(k+1))
    model.load_weights(loadweights_filepath)
    print("Compiling model")
    model.compile(optimizer=Adam(learning_rate=lr),loss='sparse_categorical_crossentropy',metrics='accuracy')
    print("Evaluating model")
    train_res = model.evaluate(train_iterator)
    loss.append(train_res[0])
    accuracy.append(train_res[1])
    val_res = model.evaluate(validation_iterator)
    val_loss.append(val_res[0])
    val_accuracy.append(val_res[1])
# Out:
# Loading model weights - Freeze
# Compiling model
# Evaluating model
# 111/111 [==============================] - 97s 854ms/step - loss: 0.1918 - accuracy: 0.9362
# 28/28 [==============================] - 24s 851ms/step - loss: 0.2909 - accuracy: 0.8939
# Loading model weights - Unfreeze 1
# Compiling model
# Evaluating model
# 111/111 [==============================] - 98s 872ms/step - loss: 0.0211 - accuracy: 0.9946
# 28/28 [==============================] - 24s 840ms/step - loss: 0.1677 - accuracy: 0.9526
# Loading model weights - Unfreeze 2
# Compiling model
# Evaluating model
# 111/111 [==============================] - 96s 852ms/step - loss: 0.0053 - accuracy: 0.9986
# 28/28 [==============================] - 24s 849ms/step - loss: 0.1993 - accuracy: 0.9515
# Loading model weights - Unfreeze 3
# Compiling model
# Evaluating model
# 111/111 [==============================] - 98s 868ms/step - loss: 0.0023 - accuracy: 0.9997
# 28/28 [==============================] - 24s 854ms/step - loss: 0.2128 - accuracy: 0.9605
# Loading model weights - Unfreeze 4
# Compiling model
# Evaluating model
# 111/111 [==============================] - 97s 860ms/step - loss: 0.0028 - accuracy: 0.9992
# 28/28 [==============================] - 24s 851ms/step - loss: 0.1788 - accuracy: 0.9616
# Loading model weights - Unfreeze 5
# Compiling model
# Evaluating model
# 111/111 [==============================] - 96s 853ms/step - loss: 7.0245e-04 - accuracy: 1.0000
# 28/28 [==============================] - 24s 859ms/step - loss: 0.2203 - accuracy: 0.9628

# %%
# Tracé des courbes de de-freeze

fig, ax = plt.subplots(1, 2, figsize=(14,6))
ax[0].plot(accuracy, color='forestgreen', marker = "*")
ax[0].plot(val_accuracy, color='lawngreen', marker = "*")
ax[0].set_title("Evolution de la précision au fil des de-freeze")
ax[0].set_xlabel("Etape de de-freeze")
ax[0].set_ylabel("Accuracy")
xticklabels=["Fully Connected\n Layers", "+Blocs 5", "+Blocs 4", "+Blocs 3", "+Blocs 2","+Blocs 1"]
ax[0].set_xticks(range(6))
ax[0].set_xticklabels(xticklabels, rotation=30, fontsize=9)
ax[0].set_ylim(0.5,1)
ax[0].legend(['train', 'validation'], loc='best');
ax[1].plot(loss, color='forestgreen', marker = "*")
ax[1].plot(val_loss, color='lawngreen', marker = "*")
ax[1].set_title("Evolution du coût au fil des de-freeze")
ax[1].set_xlabel("Etape de de-freeze")
ax[1].set_ylabel("Loss")
ax[1].set_xticks(range(6))
ax[1].set_xticklabels(xticklabels, rotation=30, fontsize=9)
ax[1].legend(['train', 'validation'], loc='best');

# %% [markdown]
# ### Evaluation du modèle

# %%
# Chargement du modèle final
model = load_model(saving_filepath)
model.compile(optimizer= Adam(learning_rate=lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# Evaluation sur les jeux train, validation et test
res = pd.DataFrame(index=['train','validation','test'],columns=['loss','accuracy'])
res.iloc[0,:] = model.evaluate(train_iterator)
res.iloc[1,:] = model.evaluate(validation_iterator)
res.iloc[2,:] = model.evaluate(test_iterator)

saving_filepath_evalu = Path('Models_training','RestNet50_lowaugm_nosegmentation','RestNet50_lowaugm_nosegmentation_results.csv')

# Sauvegarde dans un fichier CSV
res.to_csv(saving_filepath_evalu)
# Out:
# 111/111 [==============================] - 98s 872ms/step - loss: 0.0010 - accuracy: 0.9997
# 28/28 [==============================] - 24s 843ms/step - loss: 0.1678 - accuracy: 0.9639
# 35/35 [==============================] - 25s 720ms/step - loss: 0.2285 - accuracy: 0.9531

# %%
res
# Out:
#                 loss  accuracy
# train       0.001045  0.999718
# validation  0.167773  0.963883
# test        0.228501  0.953069

# %%
# Rapport de classification & matrice de confusion

def show_metrics():
    y_true = test_iterator.classes
    y_pred = model.predict(test_iterator).argmax(axis=-1)

    print(classification_report(y_true, y_pred, target_names = test_iterator.class_indices.keys()))
    
    matrix = confusion_matrix(y_true, y_pred)
    classes = test_iterator.class_indices.keys()
    sns.heatmap(matrix, annot=True,cmap="Greens", fmt = 'd',vmin=0,vmax=30,cbar=False)
    tick_marks = np.arange(0.5, len(classes), 1)
    plt.xticks(tick_marks, classes, rotation=75, fontsize = 7)
    plt.yticks(tick_marks, classes, rotation=0, fontsize = 7)
    for i, j in itertools.product(range(matrix.shape[0]), range(matrix.shape[1])):
        if (i!=j) and (matrix[i,j] !=0):
            if (matrix[i,j] > matrix.mean()):
                plt.plot((j,j,j+1,j+1,j),(i,i+1,i+1,i, i), color="red", linewidth=2)
            else:
                plt.plot((j,j,j+1,j+1,j),(i,i+1,i+1,i, i), color="k", alpha = 0.5)
    plt.ylabel("Classe réelle", fontweight = 'bold', fontsize = 12)
    plt.xlabel("Classe prédite", fontweight = 'bold', fontsize = 12)
    plt.title("Matrice de confusion", fontweight = 'extra bold', fontsize = 15);

show_metrics()
# Out:
# 35/35 [==============================] - 27s 735ms/step
#                            precision    recall  f1-score   support
#
#               Black-grass       0.69      0.74      0.71        62
#                  Charlock       1.00      0.98      0.99        90
#                  Cleavers       0.97      1.00      0.99        67
#          Common Chickweed       0.97      0.99      0.98       143
#              Common wheat       0.93      0.98      0.95        51
#                   Fat Hen       0.99      0.99      0.99       108
#          Loose Silky-bent       0.90      0.87      0.88       152
#                     Maize       1.00      0.96      0.98        51
#         Scentless Mayweed       0.98      0.98      0.98       121
#            Sheperds Purse       0.98      0.96      0.97        55
# Small-flowered Cranesbill       1.00      0.98      0.99       115
#                Sugar beet       1.00      0.97      0.98        93
#
#                  accuracy                           0.95      1108
#                 macro avg       0.95      0.95      0.95      1108
#              weighted avg       0.95      0.95      0.95      1108
