# %%
from pathlib import Path

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score

from PIL import Image
import cv2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input 
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import Callback
from timeit import default_timer as timer

import itertools
# Out:
# 2023-05-11 10:34:12.361409: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Importer le DataFrame
df = pd.read_csv("V2_Plant_Seedlings_DataFrame.csv", sep=';')
df.head()
# Out:
#                                             filepath      species image_name  \
# 0  /Users/thithaotrucle/Documents/Projet fil roug...  Black-grass      1.png
# 1  /Users/thithaotrucle/Documents/Projet fil roug...  Black-grass     10.png
# 2  /Users/thithaotrucle/Documents/Projet fil roug...  Black-grass    100.png
# 3  /Users/thithaotrucle/Documents/Projet fil roug...  Black-grass    101.png
# 4  /Users/thithaotrucle/Documents/Projet fil roug...  Black-grass    102.png
#
#    height  width      R_mean      G_mean     B_mean  luminosity  blur_score  \
# 0     138    138  105.075247   98.336957  89.631590   97.681264  151.874492
# 1    1040   1040   79.711614   68.709711  60.161677   69.527667  133.348355
# 2      82     82  111.598602  103.431440  92.232302  102.420781  131.975238
# 3     156    156   84.529668   67.176446  48.901833   66.869316  132.849602
# 4     197    197   88.982092   72.174805  53.490505   71.549134  108.609648
#
#    image_size  sharpness_score  square
# 0       19044         8.365028  square
# 1     1081600       367.182903  square
# 2        6724         2.803053  square
# 3       24336         8.426078  square
# 4       38809        12.779936  square

# %%
# Train/test split
train_df,test_df = train_test_split(df,
                                    test_size=0.2,
                                    random_state=3,
                                    shuffle=True,
                                    stratify=df['species'])

# %%
# Définition de la fonction de preprocessing incluant une étape de segmentation par seuillage
def mnv2_preprocessing_with_tsegm(threshold):
    def _mnv2_preprocessing_with_tsegm(input_img):
        # Etape 1: Segmentation simple par seuillage
        img_rgb = np.uint8(input_img)
        img_lab = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2LAB)
        img_lab = cv2.resize(img_lab,(224,224))
        # Création du masque par seuillage
        _,mask = cv2.threshold(img_lab[:,:,1],threshold,255,cv2.THRESH_BINARY_INV)
        # Elimination du bruit par ouverture puis fermeture
        kernel = np.ones((2,2))
        mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
        mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
        # Application du masque à l'image
        masked_img = cv2.bitwise_and(img_rgb,img_rgb,mask=mask)

        # Etape 2: Preprocessing propre à MobileNetV2
        final_input = preprocess_input(masked_img)
        return final_input    
    return _mnv2_preprocessing_with_tsegm

# %%
# Paramètres de preprocessing
preprocessing_function = mnv2_preprocessing_with_tsegm(threshold=118)
color_mode = 'rgb'
target_size = (224,224)
channels = 3
batch_size = 32

# %%
# Instanciation du générateur de données
train_data_generator = ImageDataGenerator(preprocessing_function=preprocessing_function,
                                          shear_range=0.3,
                                          rotation_range=90,
                                          width_shift_range=0.3, 
                                          height_shift_range=0.3,
                                          zoom_range=0.4,
                                          horizontal_flip=True,
                                          vertical_flip=True,
                                          validation_split=0.2)

test_data_generator = ImageDataGenerator(preprocessing_function=preprocessing_function)

# %%
# Instanciation des itérateurs
train_iterator = train_data_generator.flow_from_dataframe(train_df,
                                                           x_col='filepath',
                                                           y_col='species',
                                                           target_size=target_size,
                                                           color_mode=color_mode,
                                                           class_mode='sparse',
                                                           batch_size=batch_size,
                                                           subset="training")
validation_iterator = train_data_generator.flow_from_dataframe(train_df,
                                                               x_col='filepath',
                                                               y_col='species',
                                                               target_size=target_size,
                                                               color_mode=color_mode,
                                                               class_mode='sparse',
                                                               batch_size=batch_size,
                                                               subset="validation")

test_iterator = test_data_generator.flow_from_dataframe(test_df,
                                                         x_col='filepath',
                                                         y_col='species',
                                                         target_size=target_size,
                                                         color_mode=color_mode,
                                                         class_mode='sparse',
                                                         batch_size=batch_size,
                                                         shuffle=False)
# Out:
# Found 3545 validated image filenames belonging to 12 classes.
# Found 886 validated image filenames belonging to 12 classes.
# Found 1108 validated image filenames belonging to 12 classes.

# %%
# Transfer learning sur la base du modèle MobileNetV2

# Etape 1: Entraînement avec les poids du modèle MobileNetV2 pré-entraîné sur la base ImageNet

# Chargement du modèle de base pré-entraîné
base_model = MobileNetV2(include_top = False,
                        weights = 'imagenet',
                        pooling='avg')
base_model.summary()

# Freeze des poids du modèle de base
for layer in base_model.layers:
    layer.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# 2023-05-11 10:34:47.870415: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['out_relu[0][0]']
#  alAveragePooling2D)
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
# Création du modèle complet: construction fonctionnelle

inputs = Input(shape=(target_size[0],target_size[1],channels),name='Input')
          
# Définition des couches de classification
classif_layer1 = Dropout(rate=0.2,name='Dropout_layer_1')
classif_layer2 = Dense(units=256,activation='relu',name='Dense_layer_1')
classif_layer3 = Dropout(rate=0.2,name='Dropout_layer_2')
classif_layer4 = Dense(units=128,activation='relu',name='Dense_layer_2')
classif_layer5 = Dropout(rate=0.2,name='Dropout_layer_3')
output_layer = Dense(units=12,activation='softmax',name='Dense_layer_output')

# Assemblage du modèle
x = base_model(inputs)
x = classif_layer1(x)
x = classif_layer2(x)
x = classif_layer3(x)
x = classif_layer4(x)
x = classif_layer5(x)
outputs = output_layer(x)

model = Model(inputs = inputs, outputs = outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 224, 224, 3)]     0
#
#  mobilenetv2_1.00_224 (Funct  (None, 1280)             2257984
#  ional)
#
#  Dropout_layer_1 (Dropout)   (None, 1280)              0
#
#  Dense_layer_1 (Dense)       (None, 256)               327936
#
#  Dropout_layer_2 (Dropout)   (None, 256)               0
#
#  Dense_layer_2 (Dense)       (None, 128)               32896
#
#  Dropout_layer_3 (Dropout)   (None, 128)               0
#
#  Dense_layer_output (Dense)  (None, 12)                1548
#
# =================================================================
# Total params: 2,620,364
# Trainable params: 362,380
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# Définition des callbacks EarlyStopping, ReduceLROnPlateau
early_stopping = EarlyStopping(monitor='val_accuracy',
                               min_delta=0.01,
                               mode='max',
                               patience=5,
                               restore_best_weights=True,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_accuracy',
                                         factor=0.5,
                                         min_delta=0.01,
                                         mode='max',
                                         patience=3,
                                         verbose=1)


# Définition d'un callback mesurant la durée de l'entraînement 
class TimingCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_train_begin(self, logs={}):
        self.starttime = timer()
    def on_train_end(self, logs={}):
        self.logs.append(timer()-self.starttime)

time_callback = TimingCallback()

# %%
# Fonction permettant de charger un éventuel modèle précédemment entraîné, de compiler et de lancer l'entraînement

def model_load_and_fit(checkpoint_filepath,csvlogger_filepath,loadweights_filepath=None,lr=1.e-3,nb_epochs=30):
    
    # Chargement des poids obtenus lors d'un précédent entraînement
    if loadweights_filepath != None:
        model.load_weights(loadweights_filepath)
        
    # Compilation
    model.compile(optimizer=Adam(learning_rate=lr),loss='sparse_categorical_crossentropy',metrics='accuracy')
    
    # Définition du ModelCheckPoint
    model_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath,
                                       monitor='val_accuracy',
                                       mode='max',
                                       save_best_only = True,
                                       save_weights_only = True,
                                       verbose=1)
    
    # Définition du CSV Logger (enregistrement de l'historique d'entraînement)
    csv_logger = CSVLogger(csvlogger_filepath,append=True)
    
    # Entraînement
    training_history = model.fit(train_iterator,validation_data=validation_iterator,
                                 epochs=nb_epochs,
                                 steps_per_epoch=train_iterator.samples//batch_size,
                                 validation_steps=validation_iterator.samples//batch_size,
                                 callbacks=[time_callback,reduce_learning_rate,model_checkpoint,csv_logger],
                                 verbose=True)

# %%
# Définition des paramètres d'entraînement
checkpoint_filepath = Path('Models_training','MobileNetV2_AvecSeg_AvecZoom','Freeze','best_weights.ckpt')
csvlogger_filepath = Path('Models_training','MobileNetV2_AvecSeg_AvecZoom','Freeze','training_history.csv')

# %%
# Lancement de l'entraînement
model_load_and_fit(checkpoint_filepath,csvlogger_filepath)
# Out:
# Epoch 1/30
# 110/110 [==============================] - ETA: 0s - loss: 1.4126 - accuracy: 0.5147
# Epoch 1: val_accuracy improved from -inf to 0.74537, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 79s 705ms/step - loss: 1.4126 - accuracy: 0.5147 - val_loss: 0.7589 - val_accuracy: 0.7454 - lr: 0.0010
# Epoch 2/30
# 110/110 [==============================] - ETA: 0s - loss: 0.8860 - accuracy: 0.6883
# Epoch 2: val_accuracy improved from 0.74537 to 0.76968, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 74s 673ms/step - loss: 0.8860 - accuracy: 0.6883 - val_loss: 0.6400 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 3/30
# 110/110 [==============================] - ETA: 0s - loss: 0.7588 - accuracy: 0.7284
# Epoch 3: val_accuracy improved from 0.76968 to 0.77778, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 74s 671ms/step - loss: 0.7588 - accuracy: 0.7284 - val_loss: 0.5936 - val_accuracy: 0.7778 - lr: 0.0010
# Epoch 4/30
# 110/110 [==============================] - ETA: 0s - loss: 0.7053 - accuracy: 0.7526
# Epoch 4: val_accuracy improved from 0.77778 to 0.80440, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 74s 672ms/step - loss: 0.7053 - accuracy: 0.7526 - val_loss: 0.5737 - val_accuracy: 0.8044 - lr: 0.0010
# Epoch 5/30
# 110/110 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.7603
# Epoch 5: val_accuracy improved from 0.80440 to 0.82060, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 75s 682ms/step - loss: 0.6461 - accuracy: 0.7603 - val_loss: 0.5181 - val_accuracy: 0.8206 - lr: 0.0010
# Epoch 6/30
# 110/110 [==============================] - ETA: 0s - loss: 0.6319 - accuracy: 0.7666
# Epoch 6: val_accuracy did not improve from 0.82060
# 110/110 [==============================] - 75s 678ms/step - loss: 0.6319 - accuracy: 0.7666 - val_loss: 0.5506 - val_accuracy: 0.7905 - lr: 0.0010
# Epoch 7/30
# 110/110 [==============================] - ETA: 0s - loss: 0.6091 - accuracy: 0.7811
# Epoch 7: val_accuracy improved from 0.82060 to 0.82292, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 74s 671ms/step - loss: 0.6091 - accuracy: 0.7811 - val_loss: 0.5240 - val_accuracy: 0.8229 - lr: 0.0010
# Epoch 8/30
# 110/110 [==============================] - ETA: 0s - loss: 0.5657 - accuracy: 0.7908
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 8: val_accuracy did not improve from 0.82292
# 110/110 [==============================] - 74s 670ms/step - loss: 0.5657 - accuracy: 0.7908 - val_loss: 0.4971 - val_accuracy: 0.8229 - lr: 0.0010
# Epoch 9/30
# 110/110 [==============================] - ETA: 0s - loss: 0.5388 - accuracy: 0.8084
# Epoch 9: val_accuracy did not improve from 0.82292
# 110/110 [==============================] - 75s 677ms/step - loss: 0.5388 - accuracy: 0.8084 - val_loss: 0.4815 - val_accuracy: 0.8206 - lr: 5.0000e-04
# Epoch 10/30
# 110/110 [==============================] - ETA: 0s - loss: 0.5196 - accuracy: 0.8036
# Epoch 10: val_accuracy did not improve from 0.82292
# 110/110 [==============================] - 75s 682ms/step - loss: 0.5196 - accuracy: 0.8036 - val_loss: 0.5121 - val_accuracy: 0.8160 - lr: 5.0000e-04
# Epoch 11/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4979 - accuracy: 0.8170
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 11: val_accuracy did not improve from 0.82292
# 110/110 [==============================] - 76s 691ms/step - loss: 0.4979 - accuracy: 0.8170 - val_loss: 0.5066 - val_accuracy: 0.8194 - lr: 5.0000e-04
# Epoch 12/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.8170
# Epoch 12: val_accuracy improved from 0.82292 to 0.84491, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 75s 685ms/step - loss: 0.4887 - accuracy: 0.8170 - val_loss: 0.4383 - val_accuracy: 0.8449 - lr: 2.5000e-04
# Epoch 13/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4831 - accuracy: 0.8255
# Epoch 13: val_accuracy did not improve from 0.84491
# 110/110 [==============================] - 74s 673ms/step - loss: 0.4831 - accuracy: 0.8255 - val_loss: 0.4521 - val_accuracy: 0.8380 - lr: 2.5000e-04
# Epoch 14/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.8264
# Epoch 14: val_accuracy did not improve from 0.84491
# 110/110 [==============================] - 74s 672ms/step - loss: 0.4656 - accuracy: 0.8264 - val_loss: 0.4414 - val_accuracy: 0.8449 - lr: 2.5000e-04
# Epoch 15/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4649 - accuracy: 0.8343
# Epoch 15: val_accuracy improved from 0.84491 to 0.86343, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 74s 672ms/step - loss: 0.4649 - accuracy: 0.8343 - val_loss: 0.4228 - val_accuracy: 0.8634 - lr: 2.5000e-04
# Epoch 16/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4789 - accuracy: 0.8278
# Epoch 16: val_accuracy did not improve from 0.86343
# 110/110 [==============================] - 74s 671ms/step - loss: 0.4789 - accuracy: 0.8278 - val_loss: 0.4661 - val_accuracy: 0.8380 - lr: 2.5000e-04
# Epoch 17/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4827 - accuracy: 0.8252
# Epoch 17: val_accuracy did not improve from 0.86343
# 110/110 [==============================] - 74s 671ms/step - loss: 0.4827 - accuracy: 0.8252 - val_loss: 0.4146 - val_accuracy: 0.8507 - lr: 2.5000e-04
# Epoch 18/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4518 - accuracy: 0.8303
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 18: val_accuracy did not improve from 0.86343
# 110/110 [==============================] - 74s 670ms/step - loss: 0.4518 - accuracy: 0.8303 - val_loss: 0.4350 - val_accuracy: 0.8403 - lr: 2.5000e-04
# Epoch 19/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4538 - accuracy: 0.8338
# Epoch 19: val_accuracy did not improve from 0.86343
# 110/110 [==============================] - 74s 672ms/step - loss: 0.4538 - accuracy: 0.8338 - val_loss: 0.4130 - val_accuracy: 0.8553 - lr: 1.2500e-04
# Epoch 20/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4402 - accuracy: 0.8346
# Epoch 20: val_accuracy did not improve from 0.86343
# 110/110 [==============================] - 74s 673ms/step - loss: 0.4402 - accuracy: 0.8346 - val_loss: 0.4289 - val_accuracy: 0.8611 - lr: 1.2500e-04
# Epoch 21/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4229 - accuracy: 0.8409
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 21: val_accuracy did not improve from 0.86343
# 110/110 [==============================] - 74s 671ms/step - loss: 0.4229 - accuracy: 0.8409 - val_loss: 0.4140 - val_accuracy: 0.8634 - lr: 1.2500e-04
# Epoch 22/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.8363
# Epoch 22: val_accuracy did not improve from 0.86343
# 110/110 [==============================] - 75s 681ms/step - loss: 0.4283 - accuracy: 0.8363 - val_loss: 0.4503 - val_accuracy: 0.8576 - lr: 6.2500e-05
# Epoch 23/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4303 - accuracy: 0.8409
# Epoch 23: val_accuracy did not improve from 0.86343
# 110/110 [==============================] - 74s 670ms/step - loss: 0.4303 - accuracy: 0.8409 - val_loss: 0.4606 - val_accuracy: 0.8414 - lr: 6.2500e-05
# Epoch 24/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8406
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 24: val_accuracy improved from 0.86343 to 0.86690, saving model to Models_training/MobileNetV2_AvecSeg_AvecZoom/Freeze/best_weights.ckpt
# 110/110 [==============================] - 74s 673ms/step - loss: 0.4265 - accuracy: 0.8406 - val_loss: 0.3978 - val_accuracy: 0.8669 - lr: 6.2500e-05
# Epoch 25/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4302 - accuracy: 0.8377
# Epoch 25: val_accuracy did not improve from 0.86690
# 110/110 [==============================] - 74s 672ms/step - loss: 0.4302 - accuracy: 0.8377 - val_loss: 0.4006 - val_accuracy: 0.8553 - lr: 3.1250e-05
# Epoch 26/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4175 - accuracy: 0.8477
# Epoch 26: val_accuracy did not improve from 0.86690
# 110/110 [==============================] - 74s 668ms/step - loss: 0.4175 - accuracy: 0.8477 - val_loss: 0.4040 - val_accuracy: 0.8634 - lr: 3.1250e-05
# Epoch 27/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4256 - accuracy: 0.8426
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 27: val_accuracy did not improve from 0.86690
# 110/110 [==============================] - 74s 672ms/step - loss: 0.4256 - accuracy: 0.8426 - val_loss: 0.3849 - val_accuracy: 0.8576 - lr: 3.1250e-05
# Epoch 28/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4346 - accuracy: 0.8434
# Epoch 28: val_accuracy did not improve from 0.86690
# 110/110 [==============================] - 74s 672ms/step - loss: 0.4346 - accuracy: 0.8434 - val_loss: 0.4164 - val_accuracy: 0.8600 - lr: 1.5625e-05
# Epoch 29/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4134 - accuracy: 0.8477
# Epoch 29: val_accuracy did not improve from 0.86690
# 110/110 [==============================] - 74s 672ms/step - loss: 0.4134 - accuracy: 0.8477 - val_loss: 0.3909 - val_accuracy: 0.8646 - lr: 1.5625e-05
# Epoch 30/30
# 110/110 [==============================] - ETA: 0s - loss: 0.4370 - accuracy: 0.8417
# Epoch 30: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 30: val_accuracy did not improve from 0.86690
# 110/110 [==============================] - 74s 674ms/step - loss: 0.4370 - accuracy: 0.8417 - val_loss: 0.4239 - val_accuracy: 0.8576 - lr: 1.5625e-05

# %%
# Calcul de la durée de l'entrainement
print("Durée de l'entraînement:",time_callback.logs[0]//60,"minutes.")
# Out:
# Durée de l'entraînement: 37.0 minutes.

# %%
# Résultats de l'entrainement 
training_history = pd.read_csv(csvlogger_filepath,index_col = 'epoch')
training_history.head()
# Out:
#        accuracy      loss     lr  val_accuracy  val_loss
# epoch
# 0      0.514660  1.412562  0.001      0.745370  0.758896
# 1      0.688301  0.886035  0.001      0.769676  0.639979
# 2      0.728437  0.758751  0.001      0.777778  0.593567
# 3      0.752633  0.705335  0.001      0.804398  0.573656
# 4      0.760319  0.646139  0.001      0.820602  0.518128

# %%
# Trouve l'index de la ligne avec la valeur max de val_accuracy
max_val_accuracy_idx = training_history['val_accuracy'].idxmax()

# Sélectionne la ligne correspondante et affiche toutes les colonnes
row_with_max_val_accuracy = training_history.loc[max_val_accuracy_idx]
print(row_with_max_val_accuracy)

# Trouve l'index de la ligne avec la valeur min de val_accuracy
min_val_accuracy_idx = training_history['val_accuracy'].idxmin()

# Sélectionne la ligne correspondante et affiche toutes les colonnes
row_with_min_val_accuracy = training_history.loc[min_val_accuracy_idx]
print(row_with_min_val_accuracy)

column_means = training_history.mean()
print(column_means)
# Out:
# accuracy        0.840592
# loss            0.426494
# lr              0.000063
# val_accuracy    0.866898
# val_loss        0.397756
# Name: 23, dtype: float64
# accuracy        0.514660
# loss            1.412562
# lr              0.001000
# val_accuracy    0.745370
# val_loss        0.758896
# Name: 0, dtype: float64
# accuracy        0.802875
# loss            0.541581
# lr              0.000398
# val_accuracy    0.834491
# val_loss        0.473712
# dtype: float64

# %%
# Courbes de précisions et de pertes par epoch pour train et test
train_loss = training_history['loss']
val_loss = training_history['val_loss']

train_acc = training_history['accuracy']
val_acc = training_history['val_accuracy']

plt.figure(figsize=(10,5))

plt.subplot(121)
plt.plot(train_loss)
plt.plot(val_loss)
plt.title('Model loss per epoch (Sparse categorical crossentropy)')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='right')

plt.subplot(122)
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('Model accuracy per epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'], loc='right')

plt.subplots_adjust(wspace=0.43);

# %%
model.load_weights(checkpoint_filepath)

# %%
#Prédictions du classifieur
y_pred_test = model.predict(test_iterator)
y_pred_train = model.predict(train_iterator)
test_pred_class = y_pred_test.argmax(axis=1)
y_test = test_iterator.classes
# Out:
# 35/35 [==============================] - 11s 306ms/step
# 111/111 [==============================] - 63s 564ms/step

# %%
# Rapport de classification et matrice de confusion
def show_metrics(y_test, test_pred_class):
    
    #Evaluation du modèle : rapport de classification & matrice de confusion
    print(classification_report(y_test, test_pred_class, target_names = df.species.unique()))

    matrix = confusion_matrix(y_test, test_pred_class)
    classes = df.species.unique()

    sns.heatmap(matrix, annot=True,cmap="Greens", fmt = 'd')
    tick_marks = np.arange(0.5, len(classes), 1)
    plt.xticks(tick_marks, classes, rotation=75, fontsize = 7)
    plt.yticks(tick_marks, classes, rotation=0, fontsize = 7)

    for i, j in itertools.product(range(matrix.shape[0]), range(matrix.shape[1])):
        if (i!=j) and (matrix[i,j] !=0):
            if (matrix[i,j] > matrix.mean()):
                plt.plot((j,j,j+1,j+1,j),(i,i+1,i+1,i, i), color="red", linewidth=2)
            else:
                plt.plot((j,j,j+1,j+1,j),(i,i+1,i+1,i, i), color="k", alpha = 0.5)


    plt.ylabel("Classe réelle", fontweight = 'bold', fontsize = 12)
    plt.xlabel("Classe prédite", fontweight = 'bold', fontsize = 12)

    plt.title("Matrice de confusion", fontweight = 'extra bold', fontsize = 15);
    
show_metrics(y_test, test_pred_class)
# Out:
#                            precision    recall  f1-score   support
#
#               Black-grass       0.79      0.18      0.29        62
#                  Charlock       0.98      0.98      0.98        90
#                  Cleavers       0.96      0.82      0.89        67
#          Common Chickweed       0.94      0.96      0.95       143
#              Common wheat       0.81      0.90      0.85        51
#                   Fat Hen       0.90      0.95      0.92       108
#          Loose Silky-bent       0.72      0.93      0.82       152
#                     Maize       0.92      0.90      0.91        51
#         Scentless Mayweed       0.84      0.98      0.90       121
#          Shepherd’s Purse       0.81      0.76      0.79        55
# Small-flowered Cranesbill       0.98      0.98      0.98       115
#                Sugar beet       0.99      0.81      0.89        93
#
#                  accuracy                           0.88      1108
#                 macro avg       0.89      0.85      0.85      1108
#              weighted avg       0.89      0.88      0.87      1108

# %%
# Charger le meilleur entrainement
from keras import models
from keras.models import load_model   
loadweights_filepath = Path('Models_training','MobileNetV2_AvecSeg_AvecZoom','Freeze','best_weights.ckpt')
model.load_weights(loadweights_filepath)

# %%
# Evaluation du modèle
lr=1.e-3
model.compile(optimizer=Adam(learning_rate=lr),loss='sparse_categorical_crossentropy',metrics='accuracy')
res_train = model.evaluate(train_iterator)
res_valid = model.evaluate(validation_iterator)
res_test = model.evaluate(test_iterator)
# Out:
# 111/111 [==============================] - 74s 658ms/step - loss: 0.3271 - accuracy: 0.8748
# 28/28 [==============================] - 21s 761ms/step - loss: 0.4191 - accuracy: 0.8476
# 35/35 [==============================] - 15s 415ms/step - loss: 0.3096 - accuracy: 0.8809

# %%
# Définition des paramètres d'entraînement
checkpoint_filepath = Path('Models_training','MobileNetV2_AvecSeg_AvecZoom','Freeze_test','best_weights.ckpt')
csvlogger_filepath = Path('Models_training','MobileNetV2_AvecSeg_AvecZoom','Freeze_test','training_history.csv')
